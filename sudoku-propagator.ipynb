# %%
# Import z3
from z3 import *

# %% [markdown]
# #### Sudoku Puzzle Setup and Constraints
# This section initializes the Sudoku puzzle solver:
#
# - **Grid Size (N)**: Sets the size of the Sudoku grid (9x9).
#
# - **Mappings (pos_to_cell, cell_to_pos)**:
#   - `pos_to_cell`: Maps grid positions to Bit Vectors for each cell.
#   - `cell_to_pos`: Reverse mapping from Bit Vectors to grid positions.
#
# - **Constraints**:
#   - **Cell Values (val_c)**: Ensures cell values are within 1 to 9.
#   - **Row Uniqueness (row_c)**: Enforces unique values in each row.
#   - **Column Uniqueness (col_c)**: Enforces unique values in each column.
#   - **Subgrid Uniqueness (subgrid_c)**: Ensures 3x3 subgrids have unique values.
#
# These setup the framework and rules for the Sudoku solver, ensuring solutions follow standard Sudoku rules.

# %%
# Size of the sudoku grid
N = 9

# Map for position to cell
pos_to_cell = {BitVecVal(i + 1, 16): BitVec('Cell_%i' % (i + 1), 16) for i in range(N * N)}

# Map for cell to position
cell_to_pos = {v: k for k, v in pos_to_cell.items()}

# Constraints for valid cell values
val_c = [And(1 <= pos_to_cell[BitVecVal(i + 1, 16)], pos_to_cell[BitVecVal(i + 1, 16)] <= N) for i in range(N * N)]

# Constraints for distinct values in rows and columns
row_c = [Distinct([pos_to_cell[BitVecVal(i * N + j + 1, 16)] for j in range(N)]) for i in range(N)]
col_c = [Distinct([pos_to_cell[BitVecVal(i * N + j + 1, 16)] for i in range(N)]) for j in range(N)]

# Constraints for distinct values in 3x3 subgrids
subgrid_c = [Distinct([pos_to_cell[BitVecVal(subgridRow * N + subgridCol + k % 3 + N * (k // 3) + 1, 16)] for k in range(N)]) for subgridRow in range(0, N, 3) for subgridCol in range(0, N, 3)]

# %% [markdown]
# #### Class Overview: SudokuPropagator
# In the context of computational constraint satisfaction problems, `SudokuPropagator` extends the capabilities of a base constraint propagation system (`UserPropagateBase`). This class specifically addresses the complexities involved in solving Sudoku puzzles through advanced propagation techniques.
#
# - **Constructor Method (__init__)**:
#   - Inherits from `UserPropagateBase`, aligning with object-oriented programming principles.
#   - Initializes data structures: `trail` for backtracking and `lim` for maintaining backtrack boundaries.
#   - Implements lambda functions to handle fixed cell assignments (`add_fixed`) and the finalization of the puzzle state (`add_final`).
#   - Constructs a bidirectional mapping between cell identities and their respective positions within the Sudoku grid, aiding in efficient value retrieval and assignment.
#   - Registers each cell as a variable within the constraint propagation framework.
#
# - **Core Methods**:
#   - **push**: Emphasizes the importance of state preservation in backtrack-based algorithms, storing the current trail's length.
#   - **pop**: Demonstrates the backtracking mechanism, reverting state changes in response to dead-ends or conflict scenarios.
#   - **fresh**: Illustrates the concept of context-sensitive instances, generating new solver instances for varied problem contexts.
#   - **_fixed**: Operationalizes the assignment of definitive values to specific cells, marking a critical step in puzzle progression.
#   - **_fixed_trail**: Integrates trail updates with conflict checks, underlining the dynamic nature of constraint satisfaction in Sudoku.
#   - **_final**: Signifies the resolution of the puzzle, an essential component in termination conditions for constraint-based solvers.
#   - **print_grid**: Provides a visualization tool for representing the current state of the Sudoku grid, crucial for both debugging and solution verification.
#   - **check_conflict**: Enforces the foundational rules of Sudoku, ensuring no numerical duplications within rows, columns, and 3x3 subgrids, thereby maintaining the integrity of the puzzle's solution.
#
# Overall, `SudokuPropagator` encapsulates the essential elements of constraint satisfaction and propagation within the realm of Sudoku puzzles, serving as an exemplary model for understanding complex problem-solving algorithms in computational theory.

# %%
class SudokuPropagator(UserPropagateBase):
    def __init__(self, s=None, ctx=None):
        UserPropagateBase.__init__(self, s, ctx)
        self.trail = []         # Trail for storing undo actions
        self.lim = []           # Limit for the trail stack
        self.add_fixed(lambda x, v: self._fixed(x, v))  # Handler for fixed cells
        self.add_final(lambda: self._final())           # Handler for final state

        self._fixed_le = []     # List of fixed cells and their values
        self.cell_to_pos = cell_to_pos  # Mapping from cells to positions

        for _, v in pos_to_cell.items():
            self.add(v)        # Register all variables (cells)

    def push(self):
        self.lim += [len(self.trail)]  # Push current trail length onto the limit stack

    def pop(self, n):
        # Pop 'n' elements from the limit stack and undo actions on the trail stack
        head = self.lim[len(self.lim) - n]
        while len(self.trail) > head:
            self.trail[-1]()
            self.trail.pop(-1)
        self.lim = self.lim[0:len(self.lim)-n]

    def fresh(self, new_ctx):
        # Create a fresh instance of the class for a new context
        return SudokuPropagator(ctx=new_ctx)

    def _fixed(self, cell, value):
        # Handle a cell being fixed to a value
        print("Fixed: ", cell, " := ", value)
        self._fixed_trail(cell, value, self._fixed_le)

    def _fixed_trail(self, cell, value, trail):
        # Check for conflicts and add the fixed cell to the trail
        if self.check_conflict(cell, value):
            return

        trail.append((cell, value))        
        def undo():
            trail.pop(-1)
        self.trail.append(undo)

        self.print_grid()

    def _final(self):
        # Handle the final state
        print("Final")

    def print_grid(self):
        # Initialize an empty 9x9 grid
        grid = [[0 for _ in range(N)] for _ in range(N)]

        # Fill the grid with values from fixed cells
        for cell, value in self._fixed_le:
            pos = self.cell_to_pos[cell].as_long() - 1
            row, col = pos // N, pos % N
            grid[row][col] = value.as_long()

        # Print the grid
        print("Grid:")
        for row in grid:
            print(" ".join(str(num) if num != 0 else '.' for num in row))
        print()

    def check_conflict(self, cell, value):
        # Check if a cell's value conflicts with any fixed cell

        # Extract the value and convert to an integer
        value_num = value.as_long()

        # Extract the position for the cell and convert to row and column indices
        cell_pos = self.cell_to_pos[cell].as_long()
        row, col = (cell_pos - 1) // N, (cell_pos - 1) % N

        for fixed_cell in self._fixed_le:
            other_cell, other_value = fixed_cell
            other_cell_pos = self.cell_to_pos[other_cell].as_long()
            other_row, other_col = (other_cell_pos - 1) // N, (other_cell_pos - 1) % N
            other_value_num = other_value.as_long()

            # Check for conflicts in the same row, column, or subgrid
            if value_num == other_value_num:
                # Check same row or column
                if row == other_row or col == other_col:
                    print(f"Conflict: {cell}: {value_num} conflicts with {other_cell} in the same row/column")
                    self.conflict(deps=[cell, other_cell])
                    return True

                # Check same subgrid (3x3)
                if (row // 3 == other_row // 3) and (col // 3 == other_col // 3):
                    print(f"Conflict: {cell}: {value_num} conflicts with {other_cell} in the same 3x3 subgrid")
                    self.conflict(deps=[cell, other_cell])
                    return True

        return False

# %% [markdown]
# #### Function Overview: solve_sudoku
# This function demonstrates an application of constraint satisfaction principles for solving Sudoku puzzles. It encapsulates the process from initializing the problem space to finding a viable solution.
#
# - **Solver Initialization**:
#   - A `Solver` instance (`s`) is created, representing the core engine for constraint solving.
#   - `SudokuPropagator` (`sp`) is instantiated with the solver, integrating specific Sudoku puzzle solving strategies.
#
# - **Adding Constraints**:
#   - The solver is equipped with various constraints essential for Sudoku:
#     - `val_c`: Ensures all cell values are within the valid range (1 to 9).
#     - `row_c`, `col_c`, `subgrid_c` (commented out): Enforce unique values in rows, columns, and 3x3 subgrids respectively.
#   - Custom constraints based on the initial puzzle state are added, setting predefined values for certain cells.
#
# - **Solving Process**:
#   - The solver checks for the satisfiability (`s.check()`) of the imposed constraints.
#   - If a solution exists (`sat`), the model (`m`) representing the solution is used to construct the solved puzzle grid.
#   - If no solution is found, `None` is returned, indicating the puzzle's unsolvability under the given constraints.
#
# This function is an excellent representation of applying constraint satisfaction techniques in a practical setting, showcasing the integration of problem-specific constraints and the utilization of a solver to navigate the solution space.

# %%
def solve_sudoku(puzzle):
    s = Solver()
    sp = SudokuPropagator(s)

    # Add constraints for the puzzle, rows, columns, and subgrids
    # As many constraints as you like
    s.add(val_c)
    # s.add(row_c)
    # s.add(col_c)
    # s.add(subgrid_c)

    for i in range(N):
        for j in range(N):
            if puzzle[i][j] != 0:
                s.add(pos_to_cell[BitVecVal(i * N + j + 1, 16)] == puzzle[i][j])

    # Solve the puzzle
    if s.check() == sat:
        m = s.model()
        return [[m.evaluate(pos_to_cell[BitVecVal(i * N + j + 1, 16)]).as_long() for j in range(N)] for i in range(N)]
    else:
        return None

# %%
# Example puzzle to solve
puzzle = [
    [5, 3, 0, 0, 7, 0, 0, 0, 0],
    [6, 0, 0, 1, 9, 5, 0, 0, 0],
    [0, 9, 8, 0, 0, 0, 0, 6, 0],
    [8, 0, 0, 0, 6, 0, 0, 0, 3],
    [4, 0, 0, 8, 0, 3, 0, 0, 1],
    [7, 0, 0, 0, 2, 0, 0, 0, 6],
    [0, 6, 0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 4, 1, 9, 0, 0, 5],
    [0, 0, 0, 0, 8, 0, 0, 7, 9]
]

# %%
# Solve the puzzle
solution = solve_sudoku(puzzle)
# Out:
# Fixed:  Cell_1  :=  5
# Grid:
# 5 . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_2  :=  3
# Grid:
# 5 3 . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_5  :=  7
# Grid:
# 5 3 . . 7 . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_10  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_13  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_14  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_15  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_20  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_21  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_26  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_28  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_32  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_36  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_37  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_40  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_42  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_45  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_46  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_50  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . .
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_54  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . . . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_56  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . . . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_61  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 . .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_62  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . . . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_67  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 . . . . .
# . . . . . . . . .
#
# Fixed:  Cell_68  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 . . . .
# . . . . . . . . .
#
# Fixed:  Cell_69  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . .
# . . . . . . . . .
#
# Fixed:  Cell_72  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . . . . . .
#
# Fixed:  Cell_77  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . . .
#
# Fixed:  Cell_80  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 .
#
# Fixed:  Cell_81  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_79  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . 4 7 9
#
# Fixed:  Cell_78  :=  4
# Conflict: Cell_78: 4 conflicts with Cell_67 in the same 3x3 subgrid
# Fixed:  Cell_78  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 2 4 7 9
#
# Fixed:  Cell_76  :=  4
# Conflict: Cell_76: 4 conflicts with Cell_67 in the same row/column
# Fixed:  Cell_76  :=  2
# Conflict: Cell_76: 2 conflicts with Cell_78 in the same row/column
# Fixed:  Cell_76  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . 6 8 2 4 7 9
#
# Fixed:  Cell_75  :=  4
# Conflict: Cell_75: 4 conflicts with Cell_79 in the same row/column
# Fixed:  Cell_75  :=  2
# Conflict: Cell_75: 2 conflicts with Cell_78 in the same row/column
# Fixed:  Cell_75  :=  6
# Conflict: Cell_75: 6 conflicts with Cell_56 in the same 3x3 subgrid
# Fixed:  Cell_75  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . 3 6 8 2 4 7 9
#
# Fixed:  Cell_74  :=  4
# Conflict: Cell_74: 4 conflicts with Cell_79 in the same row/column
# Fixed:  Cell_74  :=  2
# Conflict: Cell_74: 2 conflicts with Cell_78 in the same row/column
# Fixed:  Cell_74  :=  6
# Conflict: Cell_74: 6 conflicts with Cell_56 in the same row/column
# Fixed:  Cell_74  :=  3
# Conflict: Cell_74: 3 conflicts with Cell_2 in the same row/column
# Fixed:  Cell_74  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_73  :=  4
# Conflict: Cell_73: 4 conflicts with Cell_37 in the same row/column
# Fixed:  Cell_73  :=  2
# Conflict: Cell_73: 2 conflicts with Cell_78 in the same row/column
# Fixed:  Cell_73  :=  6
# Conflict: Cell_73: 6 conflicts with Cell_10 in the same row/column
# Fixed:  Cell_73  :=  3
# Conflict: Cell_73: 3 conflicts with Cell_75 in the same row/column
# Fixed:  Cell_73  :=  5
# Conflict: Cell_73: 5 conflicts with Cell_1 in the same row/column
# Fixed:  Cell_73  :=  7
# Conflict: Cell_73: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_73  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# 1 . 3 6 8 2 4 7 9
#
# Fixed:  Cell_74  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_71  :=  4
# Conflict: Cell_71: 4 conflicts with Cell_67 in the same row/column
# Fixed:  Cell_71  :=  2
# Conflict: Cell_71: 2 conflicts with Cell_61 in the same 3x3 subgrid
# Fixed:  Cell_71  :=  6
# Conflict: Cell_71: 6 conflicts with Cell_26 in the same row/column
# Fixed:  Cell_71  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_70  :=  4
# Conflict: Cell_70: 4 conflicts with Cell_67 in the same row/column
# Fixed:  Cell_70  :=  2
# Conflict: Cell_70: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_70  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_66  :=  4
# Conflict: Cell_66: 4 conflicts with Cell_67 in the same row/column
# Fixed:  Cell_66  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . 2 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_65  :=  4
# Conflict: Cell_65: 4 conflicts with Cell_67 in the same row/column
# Fixed:  Cell_65  :=  2
# Conflict: Cell_65: 2 conflicts with Cell_66 in the same row/column
# Fixed:  Cell_65  :=  6
# Conflict: Cell_65: 6 conflicts with Cell_56 in the same row/column
# Fixed:  Cell_65  :=  3
# Conflict: Cell_65: 3 conflicts with Cell_2 in the same row/column
# Fixed:  Cell_65  :=  5
# Conflict: Cell_65: 5 conflicts with Cell_72 in the same row/column
# Fixed:  Cell_65  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . 7 2 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_64  :=  4
# Conflict: Cell_64: 4 conflicts with Cell_37 in the same row/column
# Fixed:  Cell_64  :=  2
# Conflict: Cell_64: 2 conflicts with Cell_66 in the same row/column
# Fixed:  Cell_64  :=  6
# Conflict: Cell_64: 6 conflicts with Cell_10 in the same row/column
# Fixed:  Cell_64  :=  3
# Conflict: Cell_64: 3 conflicts with Cell_75 in the same 3x3 subgrid
# Fixed:  Cell_64  :=  5
# Conflict: Cell_64: 5 conflicts with Cell_1 in the same row/column
# Fixed:  Cell_64  :=  7
# Conflict: Cell_64: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_64  :=  1
# Conflict: Cell_64: 1 conflicts with Cell_68 in the same row/column
# Fixed:  Cell_64  :=  8
# Conflict: Cell_64: 8 conflicts with Cell_28 in the same row/column
# Fixed:  Cell_64  :=  9
# Conflict: Cell_64: 9 conflicts with Cell_69 in the same row/column
# Fixed:  Cell_66  :=  6
# Conflict: Cell_66: 6 conflicts with Cell_56 in the same 3x3 subgrid
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# 2 . . 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_66  :=  3
# Conflict: Cell_66: 3 conflicts with Cell_75 in the same row/column
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# 2 . . 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_66  :=  5
# Conflict: Cell_66: 5 conflicts with Cell_72 in the same row/column
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . 7 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# 2 . 7 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_65  :=  7
# Conflict: Cell_65: 7 conflicts with Cell_66 in the same row/column
# Fixed:  Cell_65  :=  6
# Conflict: Cell_65: 6 conflicts with Cell_56 in the same row/column
# Fixed:  Cell_65  :=  2
# Conflict: Cell_65: 2 conflicts with Cell_64 in the same row/column
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# 2 8 7 4 1 9 6 3 5
# 1 5 3 6 8 2 4 7 9
#
# Fixed:  Cell_63  :=  4
# Conflict: Cell_63: 4 conflicts with Cell_79 in the same 3x3 subgrid
# Fixed:  Cell_63  :=  2
# Conflict: Cell_63: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_63  :=  6
# Conflict: Cell_63: 6 conflicts with Cell_54 in the same row/column
# Fixed:  Cell_63  :=  3
# Conflict: Cell_63: 3 conflicts with Cell_36 in the same row/column
# Fixed:  Cell_63  :=  5
# Conflict: Cell_63: 5 conflicts with Cell_72 in the same row/column
# Fixed:  Cell_63  :=  7
# Conflict: Cell_63: 7 conflicts with Cell_80 in the same 3x3 subgrid
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . 7 4 1 9 . . 5
# . . . . 8 . 4 7 9
#
# Fixed:  Cell_63  :=  1
# Conflict: Cell_63: 1 conflicts with Cell_45 in the same row/column
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . 7 4 1 9 . . 5
# . . . . 8 . 4 7 9
#
# Fixed:  Cell_63  :=  8
# Conflict: Cell_63: 8 conflicts with Cell_62 in the same row/column
# Fixed:  Cell_63  :=  9
# Conflict: Cell_63: 9 conflicts with Cell_81 in the same row/column
# Fixed:  Cell_63  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# . . 7 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 . 7 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_79  :=  2
# Conflict: Cell_79: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_79  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 . 7 4 1 9 . . 5
# . . . . 8 . 3 7 9
#
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . . 5
# . . . . 8 . 3 7 9
#
# Fixed:  Cell_75  :=  3
# Conflict: Cell_75: 3 conflicts with Cell_79 in the same row/column
# Fixed:  Cell_75  :=  2
# Conflict: Cell_75: 2 conflicts with Cell_64 in the same 3x3 subgrid
# Fixed:  Cell_75  :=  6
# Conflict: Cell_75: 6 conflicts with Cell_56 in the same 3x3 subgrid
# Fixed:  Cell_75  :=  7
# Conflict: Cell_75: 7 conflicts with Cell_80 in the same row/column
# Fixed:  Cell_75  :=  8
# Conflict: Cell_75: 8 conflicts with Cell_21 in the same row/column
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 . 7 4 1 9 . . 5
# . . 4 . 8 . 3 7 9
#
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . . 5
# . . 4 . 8 . 3 7 9
#
# Fixed:  Cell_78  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . . 5
# . . 4 . 8 2 3 7 9
#
# Fixed:  Cell_73  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . . 5
# 1 . 4 . 8 2 3 7 9
#
# Fixed:  Cell_71  :=  3
# Conflict: Cell_71: 3 conflicts with Cell_79 in the same 3x3 subgrid
# Fixed:  Cell_71  :=  7
# Conflict: Cell_71: 7 conflicts with Cell_80 in the same row/column
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 . 7 4 1 9 . . 5
# . . 4 . 8 . 3 7 9
#
# Fixed:  Cell_71  :=  8
# Conflict: Cell_71: 8 conflicts with Cell_62 in the same row/column
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 . 7 4 1 9 . . 5
# . . 4 . 8 . 3 7 9
#
# Fixed:  Cell_71  :=  1
# Conflict: Cell_71: 1 conflicts with Cell_68 in the same row/column
# Fixed:  Cell_71  :=  9
# Conflict: Cell_71: 9 conflicts with Cell_69 in the same row/column
# Fixed:  Cell_71  :=  5
# Conflict: Cell_71: 5 conflicts with Cell_72 in the same row/column
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . 1 7 9
#
# Fixed:  Cell_71  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . 3 5
# . . . . 8 . 1 7 9
#
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 .
# . . . 4 1 9 . 3 5
# . . 4 . 8 . 1 7 9
#
# Fixed:  Cell_63  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# . . . 4 1 9 . 3 5
# . . 4 . 8 . 1 7 9
#
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 . . 4 1 9 . 3 5
# . . 4 . 8 . 1 7 9
#
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 . 7 4 1 9 . 3 5
# . . 4 . 8 . 1 7 9
#
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# . . 4 . 8 . 1 7 9
#
# Fixed:  Cell_78  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# . . 4 . 8 2 1 7 9
#
# Fixed:  Cell_73  :=  1
# Conflict: Cell_73: 1 conflicts with Cell_79 in the same row/column
# Fixed:  Cell_73  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 . 4 . 8 2 1 7 9
#
# Fixed:  Cell_74  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_70  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_76  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . . 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_60  :=  4
# Conflict: Cell_60: 4 conflicts with Cell_67 in the same 3x3 subgrid
# Fixed:  Cell_60  :=  2
# Conflict: Cell_60: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_60  :=  6
# Conflict: Cell_60: 6 conflicts with Cell_56 in the same row/column
# Fixed:  Cell_60  :=  3
# Conflict: Cell_60: 3 conflicts with Cell_42 in the same row/column
# Fixed:  Cell_60  :=  5
# Conflict: Cell_60: 5 conflicts with Cell_15 in the same row/column
# Fixed:  Cell_60  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_59  :=  4
# Conflict: Cell_59: 4 conflicts with Cell_67 in the same 3x3 subgrid
# Fixed:  Cell_59  :=  2
# Conflict: Cell_59: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_59  :=  6
# Conflict: Cell_59: 6 conflicts with Cell_32 in the same row/column
# Fixed:  Cell_59  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_58  :=  4
# Conflict: Cell_58: 4 conflicts with Cell_67 in the same row/column
# Fixed:  Cell_58  :=  2
# Conflict: Cell_58: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_58  :=  6
# Conflict: Cell_58: 6 conflicts with Cell_56 in the same row/column
# Fixed:  Cell_58  :=  3
# Conflict: Cell_58: 3 conflicts with Cell_59 in the same row/column
# Fixed:  Cell_58  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_57  :=  4
# Conflict: Cell_57: 4 conflicts with Cell_75 in the same row/column
# Fixed:  Cell_57  :=  2
# Conflict: Cell_57: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_57  :=  6
# Conflict: Cell_57: 6 conflicts with Cell_56 in the same row/column
# Fixed:  Cell_57  :=  3
# Conflict: Cell_57: 3 conflicts with Cell_73 in the same 3x3 subgrid
# Fixed:  Cell_57  :=  5
# Conflict: Cell_57: 5 conflicts with Cell_74 in the same 3x3 subgrid
# Fixed:  Cell_57  :=  7
# Conflict: Cell_57: 7 conflicts with Cell_66 in the same row/column
# Fixed:  Cell_57  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 . . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_58  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 5 . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_59  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 5 3 . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_60  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_70  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_76  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_55  :=  4
# Conflict: Cell_55: 4 conflicts with Cell_37 in the same row/column
# Fixed:  Cell_55  :=  2
# Conflict: Cell_55: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_55  :=  6
# Conflict: Cell_55: 6 conflicts with Cell_10 in the same row/column
# Fixed:  Cell_55  :=  3
# Conflict: Cell_55: 3 conflicts with Cell_73 in the same row/column
# Fixed:  Cell_55  :=  5
# Conflict: Cell_55: 5 conflicts with Cell_1 in the same row/column
# Fixed:  Cell_55  :=  7
# Conflict: Cell_55: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_55  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 . . . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 . 4 . 8 2 1 7 9
#
# Fixed:  Cell_57  :=  1
# Conflict: Cell_57: 1 conflicts with Cell_55 in the same row/column
# Fixed:  Cell_57  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 . . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 . 4 . 8 2 1 7 9
#
# Fixed:  Cell_58  :=  5
# Conflict: Cell_58: 5 conflicts with Cell_57 in the same row/column
# Fixed:  Cell_58  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 7 . . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 . 4 . 8 2 1 7 9
#
# Fixed:  Cell_59  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 7 3 . 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 . 4 . 8 2 1 7 9
#
# Fixed:  Cell_60  :=  7
# Conflict: Cell_60: 7 conflicts with Cell_58 in the same row/column
# Fixed:  Cell_60  :=  1
# Conflict: Cell_60: 1 conflicts with Cell_68 in the same 3x3 subgrid
# Fixed:  Cell_60  :=  9
# Conflict: Cell_60: 9 conflicts with Cell_69 in the same row/column
# Fixed:  Cell_60  :=  8
# Conflict: Cell_60: 8 conflicts with Cell_62 in the same row/column
# Fixed:  Cell_60  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_55  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_57  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_58  :=  1
# Conflict: Cell_58: 1 conflicts with Cell_13 in the same row/column
# Fixed:  Cell_58  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 3 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_73  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 3 . 7 2 8 .
# . . . 4 1 9 . . 5
# 3 . . . 8 . . 7 9
#
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 3 . 7 2 8 .
# . . . 4 1 9 . . 5
# 3 . 4 . 8 . . 7 9
#
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 1 6 5 3 . 7 2 8 .
# . . . 4 1 9 . . 5
# 3 . 4 . 8 . 1 7 9
#
# Fixed:  Cell_59  :=  7
# Conflict: Cell_59: 7 conflicts with Cell_5 in the same row/column
# Fixed:  Cell_59  :=  1
# Conflict: Cell_59: 1 conflicts with Cell_68 in the same row/column
# Fixed:  Cell_59  :=  9
# Conflict: Cell_59: 9 conflicts with Cell_14 in the same row/column
# Fixed:  Cell_59  :=  5
# Conflict: Cell_59: 5 conflicts with Cell_57 in the same row/column
# Fixed:  Cell_57  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 5 . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_59  :=  8
# Conflict: Cell_59: 8 conflicts with Cell_62 in the same row/column
# Fixed:  Cell_59  :=  5
# Conflict: Cell_59: 5 conflicts with Cell_57 in the same row/column
# Fixed:  Cell_59  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 5 . 3 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_58  :=  9
# Conflict: Cell_58: 9 conflicts with Cell_69 in the same 3x3 subgrid
# Fixed:  Cell_58  :=  8
# Conflict: Cell_58: 8 conflicts with Cell_40 in the same row/column
# Fixed:  Cell_57  :=  7
# Conflict: Cell_57: 7 conflicts with Cell_60 in the same row/column
# Fixed:  Cell_57  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_59  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . 5 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_57  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 . 5 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_58  :=  8
# Conflict: Cell_58: 8 conflicts with Cell_40 in the same row/column
# Fixed:  Cell_57  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 . 5 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_58  :=  1
# Conflict: Cell_58: 1 conflicts with Cell_13 in the same row/column
# Fixed:  Cell_58  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . 3 5 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_57  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 1 3 5 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_55  :=  1
# Conflict: Cell_55: 1 conflicts with Cell_57 in the same row/column
# Fixed:  Cell_55  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_73  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . . 4 1 9 . . 5
# 3 . . . 8 . . 7 9
#
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . . 4 1 9 . . 5
# 3 . 4 . 8 . . 7 9
#
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . . 4 1 9 . . 5
# 3 . 4 . 8 . 1 7 9
#
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . . 5
# 3 . 4 . 8 . 1 7 9
#
# Fixed:  Cell_71  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 . 4 . 8 . 1 7 9
#
# Fixed:  Cell_74  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_63  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 4
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 4
# 2 . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_78  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_70  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_76  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_53  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . 4 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_52  :=  4
# Conflict: Cell_52: 4 conflicts with Cell_53 in the same row/column
# Fixed:  Cell_52  :=  2
# Conflict: Cell_52: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_52  :=  6
# Conflict: Cell_52: 6 conflicts with Cell_54 in the same row/column
# Fixed:  Cell_52  :=  3
# Conflict: Cell_52: 3 conflicts with Cell_36 in the same 3x3 subgrid
# Fixed:  Cell_52  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . 5 4 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_51  :=  4
# Conflict: Cell_51: 4 conflicts with Cell_53 in the same row/column
# Fixed:  Cell_51  :=  2
# Conflict: Cell_51: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_51  :=  6
# Conflict: Cell_51: 6 conflicts with Cell_32 in the same 3x3 subgrid
# Fixed:  Cell_51  :=  3
# Conflict: Cell_51: 3 conflicts with Cell_42 in the same row/column
# Fixed:  Cell_51  :=  5
# Conflict: Cell_51: 5 conflicts with Cell_15 in the same row/column
# Fixed:  Cell_51  :=  7
# Conflict: Cell_51: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_51  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 1 . 4 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_52  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 1 5 4 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_49  :=  4
# Conflict: Cell_49: 4 conflicts with Cell_67 in the same row/column
# Fixed:  Cell_49  :=  2
# Conflict: Cell_49: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_49  :=  6
# Conflict: Cell_49: 6 conflicts with Cell_32 in the same 3x3 subgrid
# Fixed:  Cell_49  :=  3
# Conflict: Cell_49: 3 conflicts with Cell_42 in the same 3x3 subgrid
# Fixed:  Cell_49  :=  5
# Conflict: Cell_49: 5 conflicts with Cell_52 in the same row/column
# Fixed:  Cell_49  :=  7
# Conflict: Cell_49: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_49  :=  1
# Conflict: Cell_49: 1 conflicts with Cell_13 in the same row/column
# Fixed:  Cell_49  :=  8
# Conflict: Cell_49: 8 conflicts with Cell_40 in the same row/column
# Fixed:  Cell_49  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . 9 2 1 5 4 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_48  :=  4
# Conflict: Cell_48: 4 conflicts with Cell_37 in the same 3x3 subgrid
# Fixed:  Cell_48  :=  2
# Conflict: Cell_48: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_48  :=  6
# Conflict: Cell_48: 6 conflicts with Cell_54 in the same row/column
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . 3 9 2 1 5 4 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_47  :=  4
# Conflict: Cell_47: 4 conflicts with Cell_37 in the same 3x3 subgrid
# Fixed:  Cell_47  :=  2
# Conflict: Cell_47: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_47  :=  6
# Conflict: Cell_47: 6 conflicts with Cell_54 in the same row/column
# Fixed:  Cell_47  :=  3
# Conflict: Cell_47: 3 conflicts with Cell_2 in the same row/column
# Fixed:  Cell_47  :=  5
# Conflict: Cell_47: 5 conflicts with Cell_74 in the same row/column
# Fixed:  Cell_47  :=  7
# Conflict: Cell_47: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_47  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . . 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_49  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . 9 2 . . . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_52  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . 9 2 . 5 . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_51  :=  1
# Conflict: Cell_51: 1 conflicts with Cell_47 in the same row/column
# Fixed:  Cell_51  :=  7
# Conflict: Cell_51: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_51  :=  9
# Conflict: Cell_51: 9 conflicts with Cell_69 in the same row/column
# Fixed:  Cell_51  :=  8
# Conflict: Cell_51: 8 conflicts with Cell_40 in the same 3x3 subgrid
# Fixed:  Cell_51  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . . 2 4 . . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_49  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . 9 2 4 . . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_52  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . 9 2 4 5 . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 5 . 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_53  :=  6
# Conflict: Cell_53: 6 conflicts with Cell_26 in the same row/column
# Fixed:  Cell_53  :=  5
# Conflict: Cell_53: 5 conflicts with Cell_52 in the same row/column
# Fixed:  Cell_53  :=  7
# Conflict: Cell_53: 7 conflicts with Cell_46 in the same row/column
# Fixed:  Cell_53  :=  8
# Conflict: Cell_53: 8 conflicts with Cell_62 in the same row/column
# Fixed:  Cell_53  :=  2
# Conflict: Cell_53: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_53  :=  1
# Conflict: Cell_53: 1 conflicts with Cell_45 in the same 3x3 subgrid
# Fixed:  Cell_53  :=  9
# Conflict: Cell_53: 9 conflicts with Cell_49 in the same row/column
# Fixed:  Cell_53  :=  3
# Conflict: Cell_53: 3 conflicts with Cell_36 in the same 3x3 subgrid
# Fixed:  Cell_53  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . 9 2 4 . 5 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_52  :=  1
# Conflict: Cell_52: 1 conflicts with Cell_45 in the same 3x3 subgrid
# Fixed:  Cell_52  :=  9
# Conflict: Cell_52: 9 conflicts with Cell_49 in the same row/column
# Fixed:  Cell_52  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 . 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_63  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# 2 . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_78  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_70  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_76  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_44  :=  4
# Conflict: Cell_44: 4 conflicts with Cell_37 in the same row/column
# Fixed:  Cell_44  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_43  :=  4
# Conflict: Cell_43: 4 conflicts with Cell_37 in the same row/column
# Fixed:  Cell_43  :=  2
# Conflict: Cell_43: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_43  :=  6
# Conflict: Cell_43: 6 conflicts with Cell_54 in the same 3x3 subgrid
# Fixed:  Cell_43  :=  3
# Conflict: Cell_43: 3 conflicts with Cell_36 in the same 3x3 subgrid
# Fixed:  Cell_43  :=  5
# Conflict: Cell_43: 5 conflicts with Cell_53 in the same 3x3 subgrid
# Fixed:  Cell_43  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 3 5 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_41  :=  4
# Conflict: Cell_41: 4 conflicts with Cell_37 in the same row/column
# Fixed:  Cell_41  :=  2
# Conflict: Cell_41: 2 conflicts with Cell_50 in the same row/column
# Fixed:  Cell_41  :=  6
# Conflict: Cell_41: 6 conflicts with Cell_32 in the same row/column
# Fixed:  Cell_41  :=  3
# Conflict: Cell_41: 3 conflicts with Cell_42 in the same row/column
# Fixed:  Cell_41  :=  5
# Conflict: Cell_41: 5 conflicts with Cell_59 in the same row/column
# Fixed:  Cell_41  :=  7
# Conflict: Cell_41: 7 conflicts with Cell_5 in the same row/column
# Fixed:  Cell_41  :=  1
# Conflict: Cell_41: 1 conflicts with Cell_45 in the same row/column
# Fixed:  Cell_41  :=  8
# Conflict: Cell_41: 8 conflicts with Cell_40 in the same row/column
# Fixed:  Cell_41  :=  9
# Conflict: Cell_41: 9 conflicts with Cell_14 in the same row/column
# Fixed:  Cell_41  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_53  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 . . 1
# 7 . . . 2 . . 5 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_43  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 . . . 2 . . 5 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_49  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 . . 9 2 . . 5 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_52  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 . . 9 2 . 8 5 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_47  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 1 . 9 2 . 8 5 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_51  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 1 . 9 2 4 8 5 6
# . 6 . . . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_59  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 1 . 9 2 4 8 5 6
# . 6 . . 3 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_44  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 . 9 2 4 8 5 6
# . 6 . . 3 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# . 6 . . 3 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_74  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# . 6 . . 3 7 2 8 .
# . . . 4 1 9 . . 5
# . 5 . . 8 . . 7 9
#
# Fixed:  Cell_58  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 . 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_41  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 . . 1
# 7 . . . 2 . . . 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_53  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 . . 1
# 7 . . . 2 . . 5 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_43  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 . . . 2 . . 5 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_49  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 . . 9 2 . . 5 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_52  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 . . 9 2 . 8 5 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_47  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 1 . 9 2 . 8 5 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_51  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 1 . 9 2 4 8 5 6
# . 6 . 5 . 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_59  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 . 1
# 7 1 . 9 2 4 8 5 6
# . 6 . 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_44  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 . 9 2 4 8 5 6
# . 6 . 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# . 6 . 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# . . . . 8 . . 7 9
#
# Fixed:  Cell_74  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# . 6 . 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# . 5 . . 8 . . 7 9
#
# Fixed:  Cell_57  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# . 6 1 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# . 5 . . 8 . . 7 9
#
# Fixed:  Cell_55  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# . 5 . . 8 . . 7 9
#
# Fixed:  Cell_73  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# 3 5 . . 8 . . 7 9
#
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# 3 5 4 . 8 . . 7 9
#
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 .
# . . . 4 1 9 . . 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 .
# . . 7 4 1 9 . . 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_71  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 .
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_63  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# . . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 . 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 . 1 7 9
#
# Fixed:  Cell_78  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_70  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 . 8 2 1 7 9
#
# Fixed:  Cell_76  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 2 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 5 4 6 8 2 1 7 9
#
# Fixed:  Cell_39  :=  4
# Conflict: Cell_39: 4 conflicts with Cell_37 in the same row/column
# Fixed:  Cell_39  :=  2
# Conflict: Cell_39: 2 conflicts with Cell_44 in the same row/column
# Fixed:  Cell_39  :=  6
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . . .
# . 9 8 . . . . 6 .
# 8 . . . 6 . . . 3
# ...
# . . . 4 1 9 . 3 5
# . . . . 8 6 . 7 9
#
# Fixed:  Cell_31  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 . 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . . 8 6 . 7 9
#
# Fixed:  Cell_29  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . . 8 6 . 7 9
#
# Fixed:  Cell_75  :=  9
# Conflict: Cell_75: 9 conflicts with Cell_81 in the same row/column
# Fixed:  Cell_75  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 . 8 6 . 7 9
#
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 . 8 6 . 7 9
#
# Fixed:  Cell_34  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 . 8 6 . 7 9
#
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 . 8 6 1 7 9
#
# Fixed:  Cell_24  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . 2 . 6 .
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 . 8 6 1 7 9
#
# Fixed:  Cell_19  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 .
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 . 8 6 1 7 9
#
# Fixed:  Cell_27  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 . 8 6 1 7 9
#
# Fixed:  Cell_76  :=  2
# Conflict: Cell_76: 2 conflicts with Cell_75 in the same row/column
# Fixed:  Cell_76  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 3 8 6 . 7 9
#
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 3 8 6 . 7 9
#
# Fixed:  Cell_34  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 3 8 6 . 7 9
#
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . . . 6 .
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 2 3 8 6 1 7 9
#
# Fixed:  Cell_24  :=  7
# Conflict: Cell_24: 7 conflicts with Cell_5 in the same 3x3 subgrid
# Fixed:  Cell_24  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . 2 . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 . . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . . 8 6 . 7 9
#
# Fixed:  Cell_76  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# . 9 8 . . 2 . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 . . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_19  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 .
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 . . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_27  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 . . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_47  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_33  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . . . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_75  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . . . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 3 2 8 6 . 7 9
#
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . . . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 3 2 8 6 . 7 9
#
# Fixed:  Cell_12  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . . . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 3 2 8 6 . 7 9
#
# Fixed:  Cell_30  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . 9 . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 3 2 8 6 . 7 9
#
# Fixed:  Cell_11  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 7 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . 9 . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 3 2 8 6 . 7 9
#
# Fixed:  Cell_29  :=  7
# Conflict: Cell_29: 7 conflicts with Cell_46 in the same 3x3 subgrid
# Fixed:  Cell_31  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 7 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 . 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 3 2 8 6 . 7 9
#
# Fixed:  Cell_29  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 . . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_29  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 . . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_47  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_33  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 . . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_30  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_31  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 4 2 8 6 . 7 9
#
# Fixed:  Cell_48  :=  8
# Conflict: Cell_48: 8 conflicts with Cell_21 in the same row/column
# Fixed:  Cell_47  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 . . 6 . . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_33  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 . . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_30  :=  9
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 . 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_31  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 . . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 4 2 8 6 . 7 9
#
# Fixed:  Cell_48  :=  9
# Conflict: Cell_48: 9 conflicts with Cell_30 in the same row/column
# Fixed:  Cell_48  :=  3
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . . 2 8 6 . 7 9
#
# Fixed:  Cell_75  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 4 2 8 6 . 7 9
#
# Fixed:  Cell_34  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 4 2 8 6 . 7 9
#
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 4 2 8 6 1 7 9
#
# Fixed:  Cell_12  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . . 4 2 8 6 1 7 9
#
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 4 2 8 6 1 7 9
#
# Fixed:  Cell_11  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 7 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 4 2 8 6 1 7 9
#
# Fixed:  Cell_38  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 7 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . . 4 2 8 6 1 7 9
#
# Fixed:  Cell_74  :=  6
# Conflict: Cell_74: 6 conflicts with Cell_56 in the same row/column
# Fixed:  Cell_74  :=  7
# Conflict: Cell_74: 7 conflicts with Cell_80 in the same row/column
# Fixed:  Cell_74  :=  2
# Conflict: Cell_74: 2 conflicts with Cell_76 in the same row/column
# Fixed:  Cell_74  :=  1
# Conflict: Cell_74: 1 conflicts with Cell_47 in the same row/column
# Fixed:  Cell_74  :=  9
# Conflict: Cell_74: 9 conflicts with Cell_20 in the same row/column
# Fixed:  Cell_74  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . 4 . 2 8 6 . 7 9
#
# Fixed:  Cell_75  :=  5
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 . . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . 4 5 2 8 6 . 7 9
#
# Fixed:  Cell_34  :=  4
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . 4 5 2 8 6 . 7 9
#
# Fixed:  Cell_79  :=  1
# Grid:
# 5 3 . . 7 . . . .
# 6 . . 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_12  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 . 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . . 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_66  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 . 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_11  :=  7
# Grid:
# 5 3 . . 7 . . . .
# 6 7 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 . . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_38  :=  2
# Grid:
# 5 3 . . 7 . . . .
# 6 7 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_9  :=  2
# Grid:
# 5 3 . . 7 . . . 2
# 6 7 2 1 9 5 . 4 .
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_18  :=  8
# Grid:
# 5 3 . . 7 . . . 2
# 6 7 2 1 9 5 . 4 8
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 . 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_35  :=  2
# Grid:
# 5 3 . . 7 . . . 2
# 6 7 2 1 9 5 . 4 8
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_8  :=  1
# Grid:
# 5 3 . . 7 . . 1 2
# 6 7 2 1 9 5 . 4 8
# 1 9 8 . . 2 . 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_25  :=  5
# Grid:
# 5 3 . . 7 . . 1 2
# 6 7 2 1 9 5 . 4 8
# 1 9 8 . . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_4  :=  6
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 . 4 8
# 1 9 8 . . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 . . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_51  :=  4
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 . 4 8
# 1 9 8 . . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 4 . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_22  :=  3
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 . 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 4 . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_16  :=  3
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 4 . . 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_53  :=  5
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 . 2 4 . 5 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_49  :=  9
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 . 8 5 3 7 9 1
# 7 1 3 9 2 4 . 5 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_39  :=  6
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 . 5 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_52  :=  8
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# . 6 . 5 . 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_59  :=  3
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# . 6 . 5 3 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_57  :=  1
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# . 6 1 5 3 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_55  :=  9
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# . . 7 4 1 9 . 3 5
# . 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_73  :=  3
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# . . 7 4 1 9 . 3 5
# 3 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_64  :=  2
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 . 7 4 1 9 . 3 5
# 3 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_65  :=  8
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 . 3 5
# 3 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_70  :=  6
# Grid:
# 5 3 . 6 7 . . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_6  :=  8
# Grid:
# 5 3 . 6 7 8 . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 . 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_23  :=  4
# Grid:
# 5 3 . 6 7 8 . 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 4 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_7  :=  2
# Conflict: Cell_7: 2 conflicts with Cell_61 in the same row/column
# Fixed:  Cell_7  :=  1
# Conflict: Cell_7: 1 conflicts with Cell_79 in the same row/column
# Fixed:  Cell_7  :=  9
# Grid:
# 5 3 . 6 7 8 9 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 4 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
#
# Fixed:  Cell_3  :=  4
# Grid:
# 5 3 4 6 7 8 9 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 4 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
#
# Final

# %%
# Function to print the solution
def print_sudoku(solution):
    if solution is None:
        print("No solution found.")
        return
    print("Sudoku Solution:")
    print("-" * 21)
    for i, row in enumerate(solution):
        row_str = ' | '.join(' '.join(str(cell) for cell in row[j:j+3]) for j in range(0, 9, 3))
        print(row_str)
        if i % 3 == 2:
            print("-" * 21)

# %%
# Print the solution
print_sudoku(solution)
# Out:
# Sudoku Solution:
# ---------------------
# 5 3 4 | 6 7 8 | 9 1 2
# 6 7 2 | 1 9 5 | 3 4 8
# 1 9 8 | 3 4 2 | 5 6 7
# ---------------------
# 8 5 9 | 7 6 1 | 4 2 3
# 4 2 6 | 8 5 3 | 7 9 1
# 7 1 3 | 9 2 4 | 8 5 6
# ---------------------
# 9 6 1 | 5 3 7 | 2 8 4
# 2 8 7 | 4 1 9 | 6 3 5
# 3 4 5 | 2 8 6 | 1 7 9
# ---------------------
